# %%
import matplotlib.pyplot as plt

# %%
sys_int_py = [0.034, 0.03, 0.044, 0.042, 0.045]
user_int_py = [1.6, 2.461, 9.146, 63.748, 503.86]
real_int_py = [0.254, 1.113, 7.819, 62.414, 502.2]

# %%
sys_double_py = [0.034, 0.048, 0.045, 0.044, 0.046]
user_double_py = [1.585, 2.510, 9.481, 67.824, 502.56]
real_double_py = [0.249, 1.186, 8.135, 66.497, 498.65]

# %%
sys_int_cpp = [0.004, 0.005, 0.009, 0.008, 0.020]
user_int_cpp = [0.010, 0.042, 0.152, 1.182, 10.618]
real_int_cpp = [0.014, 0.048, 0.159, 1.192, 10.650]

# %%
sys_double_cpp = [0.005, 0.006, 0.006, 0.009, 0.012]
user_double_cpp = [0.011, 0.026, 0.171, 1.216, 11.355]
real_double_cpp = [0.020, 0.030, 0.180, 1.220, 11.340]

# %%
x = [64, 128, 256, 512, 1024]

# %%
plt.figure()
plt.plot(x, sys_int_cpp, x, sys_int_py)
plt.legend(["C++", "Python"])
plt.title("System Time for INT")
plt.xlabel("N")
plt.ylabel("Time in sec")
# Out:
# Text(0, 0.5, 'Time in sec')

# %%
plt.figure()
plt.plot(x, user_int_cpp, x, user_int_py)
plt.legend(["C++", "Python"])
plt.title("User Time for INT")
plt.xlabel("N")
plt.ylabel("Time in sec")
# Out:
# Text(0, 0.5, 'Time in sec')

# %%
plt.figure()
plt.plot(x, user_double_cpp, x, user_double_py)
plt.legend(["C++", "Python"])
plt.title("User Time for Double")
plt.xlabel("N")
plt.ylabel("Time in sec")
# Out:
# Text(0, 0.5, 'Time in sec')

# %%
plt.figure()
plt.plot(x, sys_double_cpp, x, sys_double_py)
plt.legend(["C++", "Python"])
plt.title("System Time for Double")
plt.xlabel("N")
plt.ylabel("Time in sec")
# Out:
# Text(0, 0.5, 'Time in sec')
